# %% [markdown]
# # Homework of Basic Statistics
# **Telkomsel Data Science Academy**
# <br> Author: Rizli A. Anshari

# %%
import pandas as pd
import statistics as st

# %%
#1. Load googleplaystore_user_reviews.csv file from dataset folder, 
# and assign it as df_review.  
# Fill this gap (___) and uncomment the following line! 
dat = pd.read_csv('https://raw.githubusercontent.com/arikunco/basic_statistics_with_python/master/dataset/googleplaystore_user_reviews.csv', encoding='latin1')
dat.head(5)
# Out:
#                      App  ... Sentiment_Subjectivity
# 0  10 Best Foods for You  ...               0.533333
# 1  10 Best Foods for You  ...               0.288462
# 2  10 Best Foods for You  ...                    NaN
# 3  10 Best Foods for You  ...               0.875000
# 4  10 Best Foods for You  ...               0.300000
#
# [5 rows x 5 columns]

# %%
#2. How many rows and columns for df_review? 
dat.shape
# Out:
# (64295, 5)

# %%
#3. How many NaN value in dataset for each columns? 
null_columns=dat.columns[dat.isnull().any()]
dat[null_columns].isnull().sum()
# Out:
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
#4. Perform drop all NaN values and assign as new data frame named df_rev_clean
# Write your code here (Hint: dropna)
dat_clean=dat.dropna()
dat_clean.head(10)
# Out:
#                       App  ... Sentiment_Subjectivity
# 0   10 Best Foods for You  ...               0.533333
# 1   10 Best Foods for You  ...               0.288462
# 3   10 Best Foods for You  ...               0.875000
# 4   10 Best Foods for You  ...               0.300000
# 5   10 Best Foods for You  ...               0.300000
# 6   10 Best Foods for You  ...               0.900000
# 8   10 Best Foods for You  ...               0.000000
# 9   10 Best Foods for You  ...               0.000000
# 10  10 Best Foods for You  ...               0.600000
# 11  10 Best Foods for You  ...               0.100000
#
# [10 rows x 5 columns]

# %%
#5. Upon dropping, how many rows and columns remaining?
# Write your code here
dat_clean.shape
# Out:
# (37427, 5)

# %%
#6. Perform simple random sampling with only 3 sample 
# towards df_rev_clean with random_state=10 without replacement. 
# Write your code here (Hint: sample)

dat_clean.sample (n=3,random_state=10,replace=False)
# Out:
#                                    App  ... Sentiment_Subjectivity
# 12028   Badoo - Free Chat & Dating App  ...                    0.0
# 35092  Docs To Goâ¢ Free Office Suite  ...                    0.3
# 48816    Free & Premium VPN - FinchVPN  ...                    1.0
#
# [3 rows x 5 columns]

# %%
# 7. Perform stratified random sampling for each sentiment (Neutral, Positive, and Negative) 
# with the following conditions:
# 10 sample size per strata/group
# random state = 10
# without replacement
# assign as df_sample dataframe 

# Fill up the gap (___) and uncomment the following code
fn = lambda x: x.sample(n=10, random_state=10, replace=False)
dat_sample = dat_clean.groupby('Sentiment', as_index=False).apply(fn)
dat_sample.head(10)
# Out:
#                                                 App  ... Sentiment_Subjectivity
# 0 24841              Cat Sim Online: Play with Cats  ...               0.400000
#   708    30 Day Fitness Challenge - Workout at Home  ...               0.750000
#   1610                 8fit Workouts & Meal Planner  ...               0.339286
#   7306                    Anger of stick 5 : zombie  ...               0.525000
#   5843                          All Social Networks  ...               0.500000
#   40863              Etsy: Handmade & Vintage Goods  ...               0.478571
#   21756                    Calorie Counter - Macros  ...               0.426190
#   62024                           Hill Climb Racing  ...               0.254167
#   13237                         Be A Legend: Soccer  ...               0.678571
#   35864                    DoorDash - Food Delivery  ...               0.600000
#
# [10 rows x 5 columns]

# %%
#8. What is the mode value of Sentiment from df_rev_clean data frame? 

# Write your code here (Hint: sample)

st.mode(dat_clean['Sentiment'])
# Out:
# 'Positive'

# %%
#9. What is the mode value of Sentiment on df_sample data frame? Why error popped up?
# 
st.mode(dat_sample['Sentiment'])
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# <ipython-input-16-195acb876fb5> in <module>()
# ----> 1 st.mode(dat_sample['Sentiment'])
#
# /usr/lib/python3.6/statistics.py in mode(data)
#     505     elif table:
#     506         raise StatisticsError(
# --> 507                 'no unique mode; found %d equally common values' % len(table)
#     508                 )
#     509     else:
#
# StatisticsError: no unique mode; found 3 equally common values

# %%
#10. How many positive, negative, and neutral in Sentiment column of df_rev_clean data frame?

# Fill in the gap (___) and uncomment the following code
dat_clean['Sentiment'].value_counts()
# Out:
# Positive    23998
# Negative     8271
# Neutral      5158
# Name: Sentiment, dtype: int64

# %%
#11. What is the mean value of sentiment_polarity and Sentiment Subjectivity of 'Angry Birds Classic'? 

st.mean(dat_clean[dat_clean['App']=='Angry Birds Classic'].Sentiment_Subjectivity)
# Out:
# 0.5348862663965559

# %%
#12. How many Angry Birds Classic rows were included in df_rev_clean data frame?

dat_clean[dat_clean['App']=='Angry Birds Classic'].App.count()
# Out:
# 273

# %%
#13. What is the median value of sentiment polarity and Sentiment Subjectivity of 'Candy Crush Saga'?

st.median(dat_clean[dat_clean['App']=='Candy Crush Saga'].Sentiment_Polarity)
# Out:
# -0.01102272727272727

# %%
#14. What is the mode value of App in the df_rev_clean? - This apps has highest number of rows in the dataset. 

# Write your code here (Hint: st.mode)
st.mode(dat_clean.App)
# Out:
# 'Bowmasters'

# %%
#15. What is the correlation value between Sentiment Polarity and Sentiment Subjectivity 
# using spearman, pearson, and kendall

# Fill in the gap and change the method using spearman, pearson, and kendall!
# df_rev_clean.filter(like="Sentiment_").corr(method= ___)

dat_clean.filter(like='Sentiment_').corr(method='pearson')
# Out:
#                         Sentiment_Polarity  Sentiment_Subjectivity
# Sentiment_Polarity                1.000000                0.261587
# Sentiment_Subjectivity            0.261587                1.000000
